# %% [markdown]
# # Data Lineage

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - OCT images are downloaded into the cloud storage.
# - After the EDA, the training data is updated in the cloud storage.
# - After the supervised learning model, the data is augemented and stored in the cloud.
# - The augmented data is used during the semi-supervised learning portion of the model.
# - The result from the semi-supervised learning model is then provided to the user.
