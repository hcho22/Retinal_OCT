# %% [markdown]
# # 10% Labeled Semi-supervised image classification using contrastive pretraining with SimCLR

# %%
import os
import sys
import math
import tensorflow as tf
import tensorflow_datasets as tfds

from tensorflow import keras
from tensorflow.keras import layers

import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Algorithm hyperparameters
num_epochs = 100
image_channels = 3

width = 128 # number of classes that can be detected
temperature = 0.1

seed = 42
val_split   = 0.2
batch_size = 32
image_size = 224

#stronger augmentations for contrastive, weaker ones for supervised training
contrastive_augmentation = {"min_area": 0.25, "brightness": 0.6, "jitter": 0.2}
classification_augmentation = {"min_area": 0.75, "brightness": 0.3, "jitter": 0.1}

# %%
#!pip install kaggle

# %%
#import json
#import zipfile

# %%
#! mkdir ~/.kaggle
#! cp kaggle.json ~/.kaggle/
#! chmod 600 ~/.kaggle/kaggle.json
#! kaggle datasets list
#!echo '{"username":"USERNAME","key":"API_KEY"}' > /.kaggle/kaggle.json
#with open('/.kaggle/kaggle.json', 'w') as file:
#    json.dump(api_token, file)
#! kaggle datasets download -d paultimothymooney/kermany2018
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /home/ubuntu/.kaggle/kaggle.json'
# ref                                                       title                                              size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# ruchi798/data-science-job-salaries                        Data Science Job Salaries                           7KB  2022-06-15 08:59:12           8838        284  1.0
# surajjha101/bigbasket-entire-product-list-28k-datapoints  BigBasket Entire Product List (~28K datapoints)     6MB  2022-06-22 12:51:18           3102        117  1.0
# zusmani/petrolgas-prices-worldwide                        Petrol/Gas Prices Worldwide                        10KB  2022-06-24 01:25:33           2635        122  1.0
# ramjasmaurya/1-gb-internet-price                          Internet Prices around 200+ countries in 2022.     22KB  2022-07-17 02:56:12           1569         52  0.9705882
# sameepvani/nasa-nearest-earth-objects                     NASA - Nearest Earth Objects                        7MB  2022-06-17 02:32:18           2860        127  1.0
# jimschacko/airlines-dataset-to-predict-a-delay            Airlines Dataset to predict a delay                 6MB  2022-06-21 05:45:44           2611         66  1.0
# dansbecker/melbourne-housing-snapshot                     Melbourne Housing Snapshot                        451KB  2018-06-05 12:52:24          91556       1114  0.7058824
# mukuldeshantri/ecommerce-fashion-dataset                  E-commerce Dataset with 30K Products              546KB  2022-07-08 12:28:18           1030         37  1.0
# iamsouravbanerjee/nifty500-stocks-dataset                 Stock Market Dataset (NIFTY-500)                   35KB  2022-07-17 11:46:10            931         66  1.0
# gabrielsantello/cars-purchase-decision-dataset            Cars - Purchase Decision Dataset                    6KB  2022-07-09 13:18:38            782         30  1.0
# datasnaek/youtube-new                                     Trending YouTube Video Statistics                 201MB  2019-06-03 00:56:47         179754       4609  0.7941176
# zynicide/wine-reviews                                     Wine Reviews                                       51MB  2017-11-27 17:08:04         163385       3336  0.7941176
# datasnaek/chess                                           Chess Game Dataset (Lichess)                        3MB  2017-09-04 03:09:09          30565       1019  0.8235294
# rtatman/188-million-us-wildfires                          1.88 Million US Wildfires                         168MB  2020-05-12 21:03:49          20769       1022  0.8235294
# residentmario/ramen-ratings                               Ramen Ratings                                      40KB  2018-01-11 16:04:39          34881        793  0.7058824
# dansbecker/powerlifting-database                          powerlifting-database                               9MB  2019-04-30 21:07:41           4975         62  0.5882353
# jpmiller/publicassistance                                 US Public Food Assistance                         703KB  2020-08-21 16:51:18          16667        396  0.9117647
# nasa/kepler-exoplanet-search-results                      Kepler Exoplanet Search Results                     1MB  2017-10-10 18:26:59          10663        665  0.8235294
# residentmario/things-on-reddit                            Things on Reddit                                   16MB  2017-10-26 14:10:15           8698        217  0.5882353
# nolanbconaway/pitchfork-data                              18,393 Pitchfork Reviews                           33MB  2017-01-13 04:18:10          10603        371  0.7058824
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /home/ubuntu/.kaggle/kaggle.json'
# Downloading kermany2018.zip to /home/ubuntu/fourthbrain_oct/Notebooks
#   5%|█▉                                      | 522M/10.8G [00:04<01:30, 122MB/s]^C
#   5%|█▉                                      | 523M/10.8G [00:04<01:37, 114MB/s]
# User cancelled operation

# %%
#unzipping dataset
#zip_ref = zipfile.ZipFile('../Data/kermany2018.zip','r')
#zip_ref.extractall('../Data/')
#zip_ref.close()

# %%
test_path = "../Data/OCT2017 /test/"
#valid_path = "../OCT2017 /val/"
unlab_train_path = "../Data/OCT2017 /train/"
lab_train_path = "../Data/OCT2017 /10%_train/"

# %% [markdown]
# Using test data set as the labeled data set because it contains ~1k images with is ~1% of the entire dataset.
# Used 20% of the labeled data for validation set.
# Set the labels as None for the entire dataset to be considered as unlabeled.

# %%
def prepare_dataset():
      
    unlab_train_ds = (tf.keras.utils.image_dataset_from_directory(
        unlab_train_path,
        batch_size=batch_size,
        image_size= (image_size, image_size),
        #seed=seed,
        labels = None
    ))
    
    lab_train_ds = (tf.keras.utils.image_dataset_from_directory(
        lab_train_path,
        batch_size=batch_size,
        image_size=(image_size, image_size),
        seed=seed,
        validation_split=val_split,
        subset='training',
    ))
   
    test_ds = (tf.keras.utils.image_dataset_from_directory(
        lab_train_path,
        batch_size=batch_size,
        image_size=(image_size, image_size),
        seed=seed,
        validation_split=val_split,
        subset='validation',
        ))
    
    train_dataset = tf.data.Dataset.zip((unlab_train_ds, lab_train_ds)).prefetch(buffer_size=tf.data.AUTOTUNE)
    
    return train_dataset, lab_train_ds, test_ds


# Load dataset
train_dataset, labeled_train_dataset, test_dataset = prepare_dataset()
# Out:
# Found 75138 files belonging to 1 classes.
# Found 8346 files belonging to 4 classes.
# Using 6677 files for training.
# Found 8346 files belonging to 4 classes.
# Using 1669 files for validation.

# %% [markdown]
# ### Image Augmentations

# %%
# Distorts the color distributions of images
class RandomColorAffine(layers.Layer):
    def __init__(self, brightness=0, jitter = 0, **kwargs):
        super().__init__(**kwargs)
        
        self.brightness = brightness
        self.jitter = jitter
        
    def get_config(self):
        config = super().get_config()
        config.update({"brightness": self.brightness, "jitter": self.jitter})
        return config
    
    def call(self, images, training = True):
        if training:
            batch_size = tf.shape(images)[0]
            
            # Same for all colors
            brightness_scales = 1 + tf.random.uniform(
            (batch_size, 1,1,1), minval = self.brightness, maxval = self.brightness
            )
            
            # Different for all colors
            jitter_matrices = tf.random.uniform(
            (batch_size, 1, 3, 3), minval = self.jitter, maxval = self.jitter
            )
            
            color_transforms = (
            tf.eye(3, batch_shape = [batch_size, 1]) * brightness_scales + jitter_matrices
            )
            
            images = tf.clip_by_value(tf.matmul(images, color_transforms), 0, 1)
        return images

# Image augmentation module
def get_augmenter(min_area, brightness, jitter):
    zoom_factor = 1.0 - math.sqrt(min_area)
    
    return keras.Sequential(
    [
        keras.Input(shape=(image_size, image_size, image_channels)),
        layers.Rescaling(1 / 255),
        layers.RandomFlip("horizontal"),
        layers.RandomTranslation(zoom_factor / 2, zoom_factor / 2),
        layers.RandomZoom((-zoom_factor, 0.0), (-zoom_factor, 0.0)),
        RandomColorAffine(brightness, jitter)
    ])


def visualize_augmentations(num_images):
    # sample a batch from a dataset
    images = next(iter(train_dataset))[0][:num_images]

    # Apply augmentations
    augmented_images = zip(
        images,
        get_augmenter(**classification_augmentation)(images),
        get_augmenter(**contrastive_augmentation)(images),
        #get_augmenter(**contrastive_augmentation)(images),
    )
    row_titles = [
        "Original:",
        "Mildly augmented:",
        "Strongly augmented:",
        #"Strongly augmented:",
    ]
    plt.figure(figsize = (15,15))
    for column, image_row in enumerate(augmented_images):
        for row, image in enumerate(image_row):
            plt.subplot(4, num_images, row * num_images + column + 1)
            plt.imshow(image)
            if column == 0:
                plt.title(row_titles[row], loc = "left")
            plt.axis("off")
    plt.tight_layout()
    
visualize_augmentations(num_images = 5)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Basemodel Architecture

# %%
resnet50 = tf.keras.applications.resnet50.ResNet50(include_top=False, 
                                            weights=None, 
                                            input_shape = (image_size, image_size, image_channels))



def create_basemodel(resnet, 
                     input_shape,
                     dataset,
                     width,
                     n_classes):
    
    image_batch, _ = next(iter(dataset)) # extract 1 batch from the dataset
    feature_batch = resnet(image_batch)
    base_model = tf.keras.applications.ResNet50(include_top=False, weights=None)
    base_model.trainable = True
    
    inputs = tf.keras.layers.Input(shape = (image_size, image_size, image_channels))
    pool = tf.keras.layers.GlobalAveragePooling2D()
    relu = tf.keras.layers.Dense(width, activation='relu')
    
    x = inputs
    x = base_model(x)
    x = pool(x)
    out = relu(x)
    
    return tf.keras.Model(inputs=inputs, outputs=out)

# %%
n_classes = 4

create_basemodel(resnet50,(image_size,image_size,image_channels),labeled_train_dataset,width,n_classes).summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  resnet50 (Functional)       (None, None, None, 2048)  23587712
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               262272
#
# =================================================================
# Total params: 23,849,984
# Trainable params: 23,796,864
# Non-trainable params: 53,120
# _________________________________________________________________

# %% [markdown]
# ### Supervised baseline model

# %%
# Baseline supervised training with random initialization
n_classes = 4

baseline_model = keras.Sequential([
    keras.Input(shape = (image_size, image_size, image_channels)),
    get_augmenter(**classification_augmentation),
    create_basemodel(resnet50, (image_size, image_size, image_channels), labeled_train_dataset, width,n_classes),
    layers.Dense(n_classes)
],name = "baseline_model"
)


metrics = ['accuracy']
callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath='../Models/aug_supervised_model.{epoch:02d}-{val_loss:.2f}.h5',
                                                monitor='val_accuracy',
                                                mode='max',
                                                save_best_only=True),

]
optimizer = tf.keras.optimizers.Adam()

baseline_model.compile(
    optimizer = optimizer,
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics = metrics,
)

# %%
baseline_model.summary()
# Out:
# Model: "baseline_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_2 (Sequential)   (None, 224, 224, 3)       0
#
#  model_1 (Functional)        (None, 128)               23849984
#
#  dense_2 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 23,850,500
# Trainable params: 23,797,380
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
baseline_history = baseline_model.fit(
    labeled_train_dataset, 
    epochs = num_epochs, 
    validation_data = test_dataset,
    callbacks = callbacks,
)

print(
    "Maximal validation accuracy: {:.2f}%".format(
        max(baseline_history.history["val_accuracy"]) * 100
    )
)
# Out:
# Epoch 1/100
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# 209/209 [==============================] - 186s 867ms/step - loss: 0.9758 - accuracy: 0.6627 - val_loss: 1.2957 - val_accuracy: 0.4446
# Epoch 2/100
# 209/209 [==============================] - 180s 861ms/step - loss: 0.6958 - accuracy: 0.7515 - val_loss: 0.8638 - val_accuracy: 0.6926
# Epoch 3/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.5475 - accuracy: 0.8056 - val_loss: 0.8470 - val_accuracy: 0.5836
# Epoch 4/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.4823 - accuracy: 0.8284 - val_loss: 1.2808 - val_accuracy: 0.6052
# Epoch 5/100
# 209/209 [==============================] - 179s 859ms/step - loss: 0.4118 - accuracy: 0.8576 - val_loss: 1.4653 - val_accuracy: 0.5063
# Epoch 6/100
# 209/209 [==============================] - 179s 859ms/step - loss: 0.3676 - accuracy: 0.8778 - val_loss: 1.2546 - val_accuracy: 0.5656
# Epoch 7/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.3444 - accuracy: 0.8841 - val_loss: 1.3397 - val_accuracy: 0.5788
# Epoch 8/100
# 209/209 [==============================] - 180s 861ms/step - loss: 0.3155 - accuracy: 0.8937 - val_loss: 0.4341 - val_accuracy: 0.8544
# Epoch 9/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.2932 - accuracy: 0.8983 - val_loss: 1.5266 - val_accuracy: 0.5626
# Epoch 10/100
# 209/209 [==============================] - 179s 859ms/step - loss: 0.2655 - accuracy: 0.9104 - val_loss: 0.6884 - val_accuracy: 0.7627
# Epoch 11/100
# 209/209 [==============================] - 179s 859ms/step - loss: 0.2673 - accuracy: 0.9097 - val_loss: 0.6818 - val_accuracy: 0.7663
# Epoch 12/100
# 209/209 [==============================] - 179s 859ms/step - loss: 0.2580 - accuracy: 0.9151 - val_loss: 1.1672 - val_accuracy: 0.6093
# Epoch 13/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.2543 - accuracy: 0.9164 - val_loss: 0.6860 - val_accuracy: 0.7861
# Epoch 14/100
# 209/209 [==============================] - 179s 859ms/step - loss: 0.2446 - accuracy: 0.9226 - val_loss: 0.7719 - val_accuracy: 0.6417
# Epoch 15/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.2330 - accuracy: 0.9214 - val_loss: 0.9815 - val_accuracy: 0.6010
# Epoch 16/100
# 209/209 [==============================] - 180s 862ms/step - loss: 0.2377 - accuracy: 0.9229 - val_loss: 0.3709 - val_accuracy: 0.8796
# Epoch 17/100
# 209/209 [==============================] - 179s 859ms/step - loss: 0.2256 - accuracy: 0.9251 - val_loss: 0.5327 - val_accuracy: 0.8035
# Epoch 18/100
# 209/209 [==============================] - 180s 862ms/step - loss: 0.2054 - accuracy: 0.9304 - val_loss: 0.3083 - val_accuracy: 0.9023
# Epoch 19/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.2227 - accuracy: 0.9272 - val_loss: 0.3849 - val_accuracy: 0.8880
# Epoch 20/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.2197 - accuracy: 0.9256 - val_loss: 0.5785 - val_accuracy: 0.8250
# Epoch 21/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.2144 - accuracy: 0.9256 - val_loss: 0.5958 - val_accuracy: 0.7975
# Epoch 22/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.2047 - accuracy: 0.9326 - val_loss: 0.3704 - val_accuracy: 0.8856
# Epoch 23/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.1936 - accuracy: 0.9350 - val_loss: 0.8490 - val_accuracy: 0.7915
# Epoch 24/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.1952 - accuracy: 0.9334 - val_loss: 0.6238 - val_accuracy: 0.8155
# Epoch 25/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.1990 - accuracy: 0.9311 - val_loss: 0.3155 - val_accuracy: 0.9011
# Epoch 26/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.2019 - accuracy: 0.9323 - val_loss: 0.9145 - val_accuracy: 0.8113
# Epoch 27/100
# 209/209 [==============================] - 180s 862ms/step - loss: 0.1843 - accuracy: 0.9357 - val_loss: 0.3215 - val_accuracy: 0.9029
# Epoch 28/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.1983 - accuracy: 0.9347 - val_loss: 0.5420 - val_accuracy: 0.8490
# Epoch 29/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.1771 - accuracy: 0.9417 - val_loss: 0.5990 - val_accuracy: 0.7573
# Epoch 30/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.1768 - accuracy: 0.9369 - val_loss: 0.4007 - val_accuracy: 0.8838
# Epoch 31/100
# 209/209 [==============================] - 180s 862ms/step - loss: 0.1814 - accuracy: 0.9387 - val_loss: 0.3086 - val_accuracy: 0.9089
# Epoch 32/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.1767 - accuracy: 0.9432 - val_loss: 0.4949 - val_accuracy: 0.8370
# Epoch 33/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.1754 - accuracy: 0.9411 - val_loss: 0.3628 - val_accuracy: 0.8880
# Epoch 34/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.1752 - accuracy: 0.9425 - val_loss: 0.3551 - val_accuracy: 0.8730
# Epoch 35/100
# 209/209 [==============================] - 180s 861ms/step - loss: 0.1591 - accuracy: 0.9473 - val_loss: 0.2432 - val_accuracy: 0.9221
# Epoch 36/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.1611 - accuracy: 0.9429 - val_loss: 0.7081 - val_accuracy: 0.8143
# Epoch 37/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.1579 - accuracy: 0.9458 - val_loss: 0.3489 - val_accuracy: 0.9011
# Epoch 38/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.1691 - accuracy: 0.9434 - val_loss: 0.2685 - val_accuracy: 0.9155
# Epoch 39/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.1542 - accuracy: 0.9471 - val_loss: 0.2887 - val_accuracy: 0.9059
# Epoch 40/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.1527 - accuracy: 0.9491 - val_loss: 0.8298 - val_accuracy: 0.6591
# Epoch 41/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.1572 - accuracy: 0.9462 - val_loss: 0.3583 - val_accuracy: 0.9089
# Epoch 42/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.1588 - accuracy: 0.9467 - val_loss: 0.2439 - val_accuracy: 0.9215
# Epoch 43/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.1497 - accuracy: 0.9500 - val_loss: 0.5210 - val_accuracy: 0.8466
# Epoch 44/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.1439 - accuracy: 0.9509 - val_loss: 0.3511 - val_accuracy: 0.8975
# Epoch 45/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.1447 - accuracy: 0.9501 - val_loss: 0.3989 - val_accuracy: 0.8886
# Epoch 46/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.1391 - accuracy: 0.9518 - val_loss: 0.4552 - val_accuracy: 0.8718
# Epoch 47/100
# 209/209 [==============================] - 179s 858ms/step - loss: 0.1362 - accuracy: 0.9539 - val_loss: 0.2602 - val_accuracy: 0.9167
# Epoch 48/100
# 209/209 [==============================] - 180s 862ms/step - loss: 0.1343 - accuracy: 0.9536 - val_loss: 0.2352 - val_accuracy: 0.9263
# Epoch 49/100
# 209/209 [==============================] - 180s 862ms/step - loss: 0.1375 - accuracy: 0.9530 - val_loss: 0.3934 - val_accuracy: 0.8814
# Epoch 50/100
# 209/209 [==============================] - 180s 862ms/step - loss: 0.1339 - accuracy: 0.9551 - val_loss: 0.2306 - val_accuracy: 0.9299
# Epoch 51/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.1275 - accuracy: 0.9572 - val_loss: 0.4274 - val_accuracy: 0.8957
# Epoch 52/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.1340 - accuracy: 0.9560 - val_loss: 0.4733 - val_accuracy: 0.8173
# Epoch 53/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.1344 - accuracy: 0.9551 - val_loss: 0.3205 - val_accuracy: 0.9077
# Epoch 54/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.1239 - accuracy: 0.9584 - val_loss: 0.5918 - val_accuracy: 0.8490
# Epoch 55/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.1198 - accuracy: 0.9588 - val_loss: 0.3709 - val_accuracy: 0.9023
# Epoch 56/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.1292 - accuracy: 0.9570 - val_loss: 0.3096 - val_accuracy: 0.9065
# Epoch 57/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.1109 - accuracy: 0.9612 - val_loss: 0.2818 - val_accuracy: 0.9245
# Epoch 58/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.1265 - accuracy: 0.9558 - val_loss: 0.3055 - val_accuracy: 0.9095
# Epoch 59/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.1160 - accuracy: 0.9603 - val_loss: 0.2910 - val_accuracy: 0.9101
# Epoch 60/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.1152 - accuracy: 0.9620 - val_loss: 0.2988 - val_accuracy: 0.9065
# Epoch 61/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.1215 - accuracy: 0.9579 - val_loss: 0.2924 - val_accuracy: 0.9227
# Epoch 62/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.1136 - accuracy: 0.9605 - val_loss: 0.4756 - val_accuracy: 0.8874
# Epoch 63/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.1159 - accuracy: 0.9593 - val_loss: 0.2482 - val_accuracy: 0.9281
# Epoch 64/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.1055 - accuracy: 0.9615 - val_loss: 0.3081 - val_accuracy: 0.9041
# Epoch 65/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.1037 - accuracy: 0.9627 - val_loss: 0.3312 - val_accuracy: 0.9203
# Epoch 66/100
# 209/209 [==============================] - 179s 859ms/step - loss: 0.1052 - accuracy: 0.9630 - val_loss: 0.3851 - val_accuracy: 0.8892
# Epoch 67/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.1059 - accuracy: 0.9663 - val_loss: 0.2976 - val_accuracy: 0.9203
# Epoch 68/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.1048 - accuracy: 0.9647 - val_loss: 0.2683 - val_accuracy: 0.9227
# Epoch 69/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.1085 - accuracy: 0.9606 - val_loss: 0.2412 - val_accuracy: 0.9257
# Epoch 70/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0984 - accuracy: 0.9677 - val_loss: 0.2395 - val_accuracy: 0.9251
# Epoch 71/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0910 - accuracy: 0.9693 - val_loss: 0.3071 - val_accuracy: 0.9209
# Epoch 72/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.1027 - accuracy: 0.9636 - val_loss: 0.2649 - val_accuracy: 0.9263
# Epoch 73/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0931 - accuracy: 0.9662 - val_loss: 0.2706 - val_accuracy: 0.9251
# Epoch 74/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.1009 - accuracy: 0.9644 - val_loss: 0.5587 - val_accuracy: 0.8880
# Epoch 75/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0944 - accuracy: 0.9674 - val_loss: 0.3376 - val_accuracy: 0.9041
# Epoch 76/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0906 - accuracy: 0.9674 - val_loss: 0.3949 - val_accuracy: 0.8874
# Epoch 77/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0892 - accuracy: 0.9694 - val_loss: 0.2540 - val_accuracy: 0.9209
# Epoch 78/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0922 - accuracy: 0.9682 - val_loss: 0.3632 - val_accuracy: 0.9113
# Epoch 79/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0945 - accuracy: 0.9659 - val_loss: 0.8972 - val_accuracy: 0.8508
# Epoch 80/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0843 - accuracy: 0.9708 - val_loss: 0.2843 - val_accuracy: 0.9281
# Epoch 81/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0856 - accuracy: 0.9702 - val_loss: 0.3369 - val_accuracy: 0.9131
# Epoch 82/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0894 - accuracy: 0.9696 - val_loss: 0.3749 - val_accuracy: 0.9029
# Epoch 83/100
# 209/209 [==============================] - 180s 862ms/step - loss: 0.0846 - accuracy: 0.9682 - val_loss: 0.2648 - val_accuracy: 0.9311
# Epoch 84/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0784 - accuracy: 0.9729 - val_loss: 0.3884 - val_accuracy: 0.9155
# Epoch 85/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0850 - accuracy: 0.9691 - val_loss: 0.3895 - val_accuracy: 0.9179
# Epoch 86/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0812 - accuracy: 0.9693 - val_loss: 0.3037 - val_accuracy: 0.9143
# Epoch 87/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0753 - accuracy: 0.9742 - val_loss: 0.6709 - val_accuracy: 0.8670
# Epoch 88/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0734 - accuracy: 0.9742 - val_loss: 0.2894 - val_accuracy: 0.9287
# Epoch 89/100
# 209/209 [==============================] - 180s 862ms/step - loss: 0.0799 - accuracy: 0.9709 - val_loss: 0.2794 - val_accuracy: 0.9365
# Epoch 90/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0779 - accuracy: 0.9711 - val_loss: 0.3554 - val_accuracy: 0.9137
# Epoch 91/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0782 - accuracy: 0.9720 - val_loss: 0.2793 - val_accuracy: 0.9299
# Epoch 92/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0719 - accuracy: 0.9742 - val_loss: 0.6661 - val_accuracy: 0.8712
# Epoch 93/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0768 - accuracy: 0.9720 - val_loss: 0.3818 - val_accuracy: 0.9083
# Epoch 94/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0685 - accuracy: 0.9738 - val_loss: 0.3401 - val_accuracy: 0.8975
# Epoch 95/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0689 - accuracy: 0.9754 - val_loss: 0.3562 - val_accuracy: 0.9077
# Epoch 96/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0628 - accuracy: 0.9783 - val_loss: 0.4222 - val_accuracy: 0.8975
# Epoch 97/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0716 - accuracy: 0.9766 - val_loss: 0.2987 - val_accuracy: 0.9227
# Epoch 98/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0636 - accuracy: 0.9790 - val_loss: 0.3350 - val_accuracy: 0.9281
# Epoch 99/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0796 - accuracy: 0.9706 - val_loss: 0.6778 - val_accuracy: 0.8748
# Epoch 100/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0663 - accuracy: 0.9748 - val_loss: 0.3783 - val_accuracy: 0.9209
# Maximal validation accuracy: 93.65%

# %% [markdown]
# **93.65%** validation accuracy with 10% labeled data.

# %%
baseline_model.save("../Models/simclr_supervised_10%sample_100epoch_full.h5")

# %% [markdown]
# The baseline model was able to achieve 92% accuracy after 100 epochs with 10% labeled dataset.

# %%
plt.plot(baseline_history.history['accuracy'])
plt.plot(baseline_history.history['val_accuracy'])
plt.title('Supervised Learning with augmentation accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
test_batch = tf.keras.utils.image_dataset_from_directory(test_path,
                                                         image_size=(image_size, image_size),
                                                         shuffle=False,
                                                         batch_size = 1,
                                                         seed=seed,)
# Out:
# Found 968 files belonging to 4 classes.

# %%
baseline_model.load_weights('../Models/aug_supervised_model.50-0.23.h5')

# %%
baseline_model.evaluate(test_batch)
# Out:
# 968/968 [==============================] - 28s 29ms/step - loss: 0.0857 - accuracy: 0.9814
# [0.08568251132965088, 0.9814049601554871]

# %% [markdown]
# Augmented supervised learning model on 10% labeled data achieved 98% accuracy.

# %% [markdown]
# ### Self-supervised model for contrastive pretraining

# %%
# Define the contrastive model with model-subclassing
class ContrastiveModel(keras.Model):
    def __init__(self):
        super().__init__()

        self.temperature = temperature
        self.contrastive_augmenter = get_augmenter(**contrastive_augmentation)
        self.classification_augmenter = get_augmenter(**classification_augmentation)
        self.encoder =  create_basemodel(resnet50, (image_size, image_size, image_channels), labeled_train_dataset, width,4)
        # Non-linear MLP as projection head - Note, output is of width width. This is okay as we use matrix calculations to reduce the size to a single loss value per step
        self.projection_head = keras.Sequential(
            [
                keras.Input(shape=(width,)),
                layers.Dense(width, activation="relu"),
                layers.Dense(width),
            ],
            name="projection_head",
        )
        # Single dense layer for linear probing
        self.linear_probe = keras.Sequential(
            [layers.Input(shape=(width,)), layers.Dense(4)], name="linear_probe"
        )

        self.encoder.summary()
        self.projection_head.summary()
        self.linear_probe.summary()

    def compile(self, contrastive_optimizer, probe_optimizer, **kwargs):
        super().compile(**kwargs)

        self.contrastive_optimizer = contrastive_optimizer
        self.probe_optimizer = probe_optimizer

        # self.contrastive_loss will be defined as a method
        self.probe_loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True)

        self.contrastive_loss_tracker = keras.metrics.Mean(name="c_loss")
        self.contrastive_accuracy = keras.metrics.SparseCategoricalAccuracy(name="c_acc")
        
        self.probe_loss_tracker = keras.metrics.Mean(name="p_loss")
        self.probe_accuracy = keras.metrics.SparseCategoricalAccuracy(name="p_acc")

    @property
    def metrics(self):
        """These are metrics we want to print and carry through our gradient tape"""
        return [
            self.contrastive_loss_tracker,
            self.contrastive_accuracy,
            self.probe_loss_tracker,
            self.probe_accuracy,
        ]

    def contrastive_loss(self, projections_1, projections_2):
        # InfoNCE loss (information noise-contrastive estimation)
        # NT-Xent loss (normalized temperature-scaled cross entropy)

        # Cosine similarity: the dot product of the l2-normalized feature vectors
        projections_1 = tf.math.l2_normalize(projections_1, axis=1)
        projections_2 = tf.math.l2_normalize(projections_2, axis=1)
        similarities = (
            tf.matmul(projections_1, projections_2, transpose_b=True) / self.temperature
        )

        # The similarity between the representations of two augmented views of the
        # same image should be higher than their similarity with other views
        batch_size = tf.shape(projections_1)[0]
        contrastive_labels = tf.range(batch_size)
        self.contrastive_accuracy.update_state(contrastive_labels, similarities)
        self.contrastive_accuracy.update_state(
            contrastive_labels, tf.transpose(similarities)
        )

        # The temperature-scaled similarities are used as logits for cross-entropy
        # a symmetrized version of the loss is used here
        loss_1_2 = keras.losses.sparse_categorical_crossentropy(
            contrastive_labels, similarities, from_logits=True
        )
        loss_2_1 = keras.losses.sparse_categorical_crossentropy(
            contrastive_labels, tf.transpose(similarities), from_logits=True
        )
        return (loss_1_2 + loss_2_1) / 2

    def train_step(self, data):
        unlabeled_images, (labeled_images, labels) = data

        # Both labeled and unlabeled images are used, without labels
        images = tf.concat((unlabeled_images, labeled_images), axis=0)
        # Each image is augmented twice, differently
        augmented_images_1 = self.contrastive_augmenter(images, training=True)
        augmented_images_2 = self.contrastive_augmenter(images, training=True)
        with tf.GradientTape() as tape:
            features_1 = self.encoder(augmented_images_1, training=True)
            features_2 = self.encoder(augmented_images_2, training=True)
            # The representations are passed through a projection mlp
            projections_1 = self.projection_head(features_1, training=True)
            projections_2 = self.projection_head(features_2, training=True)
            contrastive_loss = self.contrastive_loss(projections_1, projections_2)
        gradients = tape.gradient(
            contrastive_loss,
            self.encoder.trainable_weights + self.projection_head.trainable_weights,
        )
        self.contrastive_optimizer.apply_gradients(
            zip(
                gradients,
                self.encoder.trainable_weights + self.projection_head.trainable_weights,
            )
        )
        self.contrastive_loss_tracker.update_state(contrastive_loss)

        # Labels are only used in evalutation for an on-the-fly logistic regression
        preprocessed_images = self.classification_augmenter(
            labeled_images, training=True
        )
        with tf.GradientTape() as tape:
            # the encoder is used in inference mode here to avoid regularization
            # and updating the batch normalization paramers if they are used
            features = self.encoder(preprocessed_images, training=False)
            class_logits = self.linear_probe(features, training=True)
            probe_loss = self.probe_loss(labels, class_logits)
        gradients = tape.gradient(probe_loss, self.linear_probe.trainable_weights)
        self.probe_optimizer.apply_gradients(
            zip(gradients, self.linear_probe.trainable_weights)
        )
        self.probe_loss_tracker.update_state(probe_loss)
        self.probe_accuracy.update_state(labels, class_logits)

        return {m.name: m.result() for m in self.metrics}

    def test_step(self, data):
        labeled_images, labels = data

        # For testing the components are used with a training=False flag
        preprocessed_images = self.classification_augmenter(
            labeled_images, training=False
        )
        features = self.encoder(preprocessed_images, training=False)
        class_logits = self.linear_probe(features, training=False)
        probe_loss = self.probe_loss(labels, class_logits)
        self.probe_loss_tracker.update_state(probe_loss)
        self.probe_accuracy.update_state(labels, class_logits)

        # Only the probe metrics are logged at test time
        return {m.name: m.result() for m in self.metrics[2:]}

# %%
# Contrastive pretraining
pretraining_model = ContrastiveModel()#calls the class, which has the inits in it 
pretraining_model.compile(
    contrastive_optimizer=keras.optimizers.Adam(),
    probe_optimizer=keras.optimizers.Adam(),
)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_13 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  resnet50 (Functional)       (None, None, None, 2048)  23587712
#
#  global_average_pooling2d_2   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_3 (Dense)             (None, 128)               262272
#
# =================================================================
# Total params: 23,849,984
# Trainable params: 23,796,864
# Non-trainable params: 53,120
# _________________________________________________________________
# Model: "projection_head"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 128)               16512
#
#  dense_5 (Dense)             (None, 128)               16512
#
# =================================================================
# Total params: 33,024
# Trainable params: 33,024
# Non-trainable params: 0
# _________________________________________________________________
# Model: "linear_probe"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 516
# Trainable params: 516
# Non-trainable params: 0
# _________________________________________________________________

# %%
callbacks2 = [#tf.keras.callbacks.EarlyStopping(patience=3, monitor='val_loss', ),
tf.keras.callbacks.ModelCheckpoint(filepath='../Models/pretraining_model.{epoch:02d}-{val_p_loss:.2f}.h5',
                                                monitor='val_accuracy',
                                                mode='max',
                                                save_best_only=True),

]


pretraining_history = pretraining_model.fit(
    train_dataset, 
    epochs=num_epochs, 
    validation_data=test_dataset,
    callbacks = callbacks2
)
print(
    "Maximal validation accuracy: {:.2f}%".format(
        max(pretraining_history.history["val_p_acc"]) * 100
    )
)
# Out:
# Epoch 1/100
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# 209/209 [==============================] - ETA: 0s - c_loss: 2.3338 - c_acc: 0.3463 - p_loss: 8.0504 - p_acc: 0.2934WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 581s 3s/step - c_loss: 2.3338 - c_acc: 0.3463 - p_loss: 8.0504 - p_acc: 0.2934 - val_p_loss: 5.4928 - val_p_acc: 0.4032
# Epoch 2/100
# 209/209 [==============================] - ETA: 0s - c_loss: 1.1751 - c_acc: 0.6746 - p_loss: 5.7203 - p_acc: 0.3311WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 1.1751 - c_acc: 0.6746 - p_loss: 5.7203 - p_acc: 0.3311 - val_p_loss: 2.7656 - val_p_acc: 0.3841
# Epoch 3/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.7809 - c_acc: 0.7893 - p_loss: 3.0955 - p_acc: 0.3541WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.7809 - c_acc: 0.7893 - p_loss: 3.0955 - p_acc: 0.3541 - val_p_loss: 2.5779 - val_p_acc: 0.4518
# Epoch 4/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.6643 - c_acc: 0.8214 - p_loss: 2.7365 - p_acc: 0.3988WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.6643 - c_acc: 0.8214 - p_loss: 2.7365 - p_acc: 0.3988 - val_p_loss: 2.0857 - val_p_acc: 0.3607
# Epoch 5/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.5519 - c_acc: 0.8578 - p_loss: 2.3765 - p_acc: 0.4304WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.5519 - c_acc: 0.8578 - p_loss: 2.3765 - p_acc: 0.4304 - val_p_loss: 2.2996 - val_p_acc: 0.4416
# Epoch 6/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.4760 - c_acc: 0.8800 - p_loss: 2.1802 - p_acc: 0.4445WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.4760 - c_acc: 0.8800 - p_loss: 2.1802 - p_acc: 0.4445 - val_p_loss: 1.5947 - val_p_acc: 0.3523
# Epoch 7/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.4336 - c_acc: 0.8924 - p_loss: 1.9049 - p_acc: 0.4851WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.4336 - c_acc: 0.8924 - p_loss: 1.9049 - p_acc: 0.4851 - val_p_loss: 1.3644 - val_p_acc: 0.3379
# Epoch 8/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.3990 - c_acc: 0.9019 - p_loss: 1.6374 - p_acc: 0.4899WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.3990 - c_acc: 0.9019 - p_loss: 1.6374 - p_acc: 0.4899 - val_p_loss: 1.6225 - val_p_acc: 0.4488
# Epoch 9/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.3537 - c_acc: 0.9156 - p_loss: 1.5606 - p_acc: 0.5365WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.3537 - c_acc: 0.9156 - p_loss: 1.5606 - p_acc: 0.5365 - val_p_loss: 1.7209 - val_p_acc: 0.4056
# Epoch 10/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.3361 - c_acc: 0.9229 - p_loss: 1.4006 - p_acc: 0.5583WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.3361 - c_acc: 0.9229 - p_loss: 1.4006 - p_acc: 0.5583 - val_p_loss: 1.7357 - val_p_acc: 0.3978
# Epoch 11/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.3208 - c_acc: 0.9234 - p_loss: 1.2791 - p_acc: 0.5875WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.3208 - c_acc: 0.9234 - p_loss: 1.2791 - p_acc: 0.5875 - val_p_loss: 1.5049 - val_p_acc: 0.5123
# Epoch 12/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.3065 - c_acc: 0.9274 - p_loss: 1.3428 - p_acc: 0.5670WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.3065 - c_acc: 0.9274 - p_loss: 1.3428 - p_acc: 0.5670 - val_p_loss: 1.7409 - val_p_acc: 0.3379
# Epoch 13/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.2811 - c_acc: 0.9354 - p_loss: 1.2050 - p_acc: 0.5866WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.2811 - c_acc: 0.9354 - p_loss: 1.2050 - p_acc: 0.5866 - val_p_loss: 1.8385 - val_p_acc: 0.3445
# Epoch 14/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.2879 - c_acc: 0.9336 - p_loss: 1.1471 - p_acc: 0.6226WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.2879 - c_acc: 0.9336 - p_loss: 1.1471 - p_acc: 0.6226 - val_p_loss: 1.6000 - val_p_acc: 0.2720
# Epoch 15/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.2667 - c_acc: 0.9410 - p_loss: 1.2386 - p_acc: 0.6031WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.2667 - c_acc: 0.9410 - p_loss: 1.2386 - p_acc: 0.6031 - val_p_loss: 1.4028 - val_p_acc: 0.3469
# Epoch 16/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.2380 - c_acc: 0.9480 - p_loss: 1.2018 - p_acc: 0.6060WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.2380 - c_acc: 0.9480 - p_loss: 1.2018 - p_acc: 0.6060 - val_p_loss: 2.4105 - val_p_acc: 0.3445
# Epoch 17/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.2441 - c_acc: 0.9473 - p_loss: 1.2955 - p_acc: 0.6081WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.2441 - c_acc: 0.9473 - p_loss: 1.2955 - p_acc: 0.6081 - val_p_loss: 1.9482 - val_p_acc: 0.4440
# Epoch 18/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.2491 - c_acc: 0.9452 - p_loss: 1.1370 - p_acc: 0.6232WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.2491 - c_acc: 0.9452 - p_loss: 1.1370 - p_acc: 0.6232 - val_p_loss: 1.3927 - val_p_acc: 0.4560
# Epoch 19/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.2255 - c_acc: 0.9517 - p_loss: 1.1926 - p_acc: 0.6287WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.2255 - c_acc: 0.9517 - p_loss: 1.1926 - p_acc: 0.6287 - val_p_loss: 1.4631 - val_p_acc: 0.5470
# Epoch 20/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.2215 - c_acc: 0.9536 - p_loss: 1.2308 - p_acc: 0.6343WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.2215 - c_acc: 0.9536 - p_loss: 1.2308 - p_acc: 0.6343 - val_p_loss: 1.3574 - val_p_acc: 0.3493
# Epoch 21/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.2101 - c_acc: 0.9559 - p_loss: 1.0015 - p_acc: 0.6620WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.2101 - c_acc: 0.9559 - p_loss: 1.0015 - p_acc: 0.6620 - val_p_loss: 1.5276 - val_p_acc: 0.4350
# Epoch 22/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.2106 - c_acc: 0.9564 - p_loss: 1.0880 - p_acc: 0.6307WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.2106 - c_acc: 0.9564 - p_loss: 1.0880 - p_acc: 0.6307 - val_p_loss: 1.1079 - val_p_acc: 0.5333
# Epoch 23/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.2113 - c_acc: 0.9568 - p_loss: 1.1685 - p_acc: 0.6476WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.2113 - c_acc: 0.9568 - p_loss: 1.1685 - p_acc: 0.6476 - val_p_loss: 1.6170 - val_p_acc: 0.2924
# Epoch 24/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1970 - c_acc: 0.9600 - p_loss: 1.0781 - p_acc: 0.6522WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.1970 - c_acc: 0.9600 - p_loss: 1.0781 - p_acc: 0.6522 - val_p_loss: 1.3064 - val_p_acc: 0.3925
# Epoch 25/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1882 - c_acc: 0.9623 - p_loss: 1.0881 - p_acc: 0.6448WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.1882 - c_acc: 0.9623 - p_loss: 1.0881 - p_acc: 0.6448 - val_p_loss: 2.0431 - val_p_acc: 0.3229
# Epoch 26/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1848 - c_acc: 0.9631 - p_loss: 1.0968 - p_acc: 0.6525WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.1848 - c_acc: 0.9631 - p_loss: 1.0968 - p_acc: 0.6525 - val_p_loss: 1.8321 - val_p_acc: 0.3307
# Epoch 27/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1921 - c_acc: 0.9618 - p_loss: 1.0876 - p_acc: 0.6561WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.1921 - c_acc: 0.9618 - p_loss: 1.0876 - p_acc: 0.6561 - val_p_loss: 1.6117 - val_p_acc: 0.3104
# Epoch 28/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1811 - c_acc: 0.9633 - p_loss: 0.9159 - p_acc: 0.6799WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.1811 - c_acc: 0.9633 - p_loss: 0.9159 - p_acc: 0.6799 - val_p_loss: 1.5466 - val_p_acc: 0.4548
# Epoch 29/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1844 - c_acc: 0.9634 - p_loss: 1.0067 - p_acc: 0.6642WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.1844 - c_acc: 0.9634 - p_loss: 1.0067 - p_acc: 0.6642 - val_p_loss: 1.2625 - val_p_acc: 0.4098
# Epoch 30/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1761 - c_acc: 0.9652 - p_loss: 0.9969 - p_acc: 0.6693WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.1761 - c_acc: 0.9652 - p_loss: 0.9969 - p_acc: 0.6693 - val_p_loss: 1.6048 - val_p_acc: 0.3421
# Epoch 31/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1687 - c_acc: 0.9681 - p_loss: 0.9564 - p_acc: 0.6781WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.1687 - c_acc: 0.9681 - p_loss: 0.9564 - p_acc: 0.6781 - val_p_loss: 1.4251 - val_p_acc: 0.4536
# Epoch 32/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1682 - c_acc: 0.9685 - p_loss: 0.9649 - p_acc: 0.6874WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.1682 - c_acc: 0.9685 - p_loss: 0.9649 - p_acc: 0.6874 - val_p_loss: 1.4112 - val_p_acc: 0.3948
# Epoch 33/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1571 - c_acc: 0.9714 - p_loss: 1.0348 - p_acc: 0.6750WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.1571 - c_acc: 0.9714 - p_loss: 1.0348 - p_acc: 0.6750 - val_p_loss: 1.3102 - val_p_acc: 0.4937
# Epoch 34/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1623 - c_acc: 0.9695 - p_loss: 1.0074 - p_acc: 0.6780WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.1623 - c_acc: 0.9695 - p_loss: 1.0074 - p_acc: 0.6780 - val_p_loss: 1.3213 - val_p_acc: 0.4410
# Epoch 35/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1488 - c_acc: 0.9733 - p_loss: 0.8555 - p_acc: 0.7029WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.1488 - c_acc: 0.9733 - p_loss: 0.8555 - p_acc: 0.7029 - val_p_loss: 1.2125 - val_p_acc: 0.5315
# Epoch 36/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1495 - c_acc: 0.9734 - p_loss: 0.8758 - p_acc: 0.6915WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.1495 - c_acc: 0.9734 - p_loss: 0.8758 - p_acc: 0.6915 - val_p_loss: 1.1565 - val_p_acc: 0.5291
# Epoch 37/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1509 - c_acc: 0.9715 - p_loss: 1.0614 - p_acc: 0.6657WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.1509 - c_acc: 0.9715 - p_loss: 1.0614 - p_acc: 0.6657 - val_p_loss: 1.3874 - val_p_acc: 0.5123
# Epoch 38/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1474 - c_acc: 0.9732 - p_loss: 0.8981 - p_acc: 0.6948WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.1474 - c_acc: 0.9732 - p_loss: 0.8981 - p_acc: 0.6948 - val_p_loss: 1.2551 - val_p_acc: 0.4871
# Epoch 39/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1481 - c_acc: 0.9731 - p_loss: 0.8777 - p_acc: 0.6925WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.1481 - c_acc: 0.9731 - p_loss: 0.8777 - p_acc: 0.6925 - val_p_loss: 1.5769 - val_p_acc: 0.3637
# Epoch 40/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1442 - c_acc: 0.9749 - p_loss: 0.9864 - p_acc: 0.6801WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.1442 - c_acc: 0.9749 - p_loss: 0.9864 - p_acc: 0.6801 - val_p_loss: 1.3111 - val_p_acc: 0.3919
# Epoch 41/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1404 - c_acc: 0.9745 - p_loss: 0.8522 - p_acc: 0.7057WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.1404 - c_acc: 0.9745 - p_loss: 0.8522 - p_acc: 0.7057 - val_p_loss: 1.1540 - val_p_acc: 0.5476
# Epoch 42/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1440 - c_acc: 0.9734 - p_loss: 0.8941 - p_acc: 0.6952WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.1440 - c_acc: 0.9734 - p_loss: 0.8941 - p_acc: 0.6952 - val_p_loss: 1.8162 - val_p_acc: 0.3637
# Epoch 43/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1364 - c_acc: 0.9753 - p_loss: 0.9196 - p_acc: 0.6949WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.1364 - c_acc: 0.9753 - p_loss: 0.9196 - p_acc: 0.6949 - val_p_loss: 1.4108 - val_p_acc: 0.5099
# Epoch 44/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1329 - c_acc: 0.9762 - p_loss: 0.8673 - p_acc: 0.7009WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.1329 - c_acc: 0.9762 - p_loss: 0.8673 - p_acc: 0.7009 - val_p_loss: 1.2029 - val_p_acc: 0.5045
# Epoch 45/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1351 - c_acc: 0.9759 - p_loss: 0.8692 - p_acc: 0.6982WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.1351 - c_acc: 0.9759 - p_loss: 0.8692 - p_acc: 0.6982 - val_p_loss: 1.5182 - val_p_acc: 0.3571
# Epoch 46/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1349 - c_acc: 0.9773 - p_loss: 0.9264 - p_acc: 0.7009WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.1349 - c_acc: 0.9773 - p_loss: 0.9264 - p_acc: 0.7009 - val_p_loss: 1.2732 - val_p_acc: 0.4500
# Epoch 47/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1220 - c_acc: 0.9799 - p_loss: 0.8634 - p_acc: 0.7136WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.1220 - c_acc: 0.9799 - p_loss: 0.8634 - p_acc: 0.7136 - val_p_loss: 1.3489 - val_p_acc: 0.4554
# Epoch 48/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1287 - c_acc: 0.9777 - p_loss: 0.8388 - p_acc: 0.7057WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.1287 - c_acc: 0.9777 - p_loss: 0.8388 - p_acc: 0.7057 - val_p_loss: 1.2576 - val_p_acc: 0.4098
# Epoch 49/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1268 - c_acc: 0.9775 - p_loss: 0.8487 - p_acc: 0.7118WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.1268 - c_acc: 0.9775 - p_loss: 0.8487 - p_acc: 0.7118 - val_p_loss: 1.3313 - val_p_acc: 0.4020
# Epoch 50/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1258 - c_acc: 0.9774 - p_loss: 0.9336 - p_acc: 0.6987WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.1258 - c_acc: 0.9774 - p_loss: 0.9336 - p_acc: 0.6987 - val_p_loss: 1.4972 - val_p_acc: 0.3841
# Epoch 51/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1284 - c_acc: 0.9785 - p_loss: 0.8270 - p_acc: 0.7145WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.1284 - c_acc: 0.9785 - p_loss: 0.8270 - p_acc: 0.7145 - val_p_loss: 1.1786 - val_p_acc: 0.5093
# Epoch 52/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1175 - c_acc: 0.9813 - p_loss: 0.8419 - p_acc: 0.7130WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.1175 - c_acc: 0.9813 - p_loss: 0.8419 - p_acc: 0.7130 - val_p_loss: 1.7335 - val_p_acc: 0.3990
# Epoch 53/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1181 - c_acc: 0.9809 - p_loss: 0.7515 - p_acc: 0.7331WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.1181 - c_acc: 0.9809 - p_loss: 0.7515 - p_acc: 0.7331 - val_p_loss: 1.4509 - val_p_acc: 0.3313
# Epoch 54/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1169 - c_acc: 0.9824 - p_loss: 0.7834 - p_acc: 0.7235WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.1169 - c_acc: 0.9824 - p_loss: 0.7834 - p_acc: 0.7235 - val_p_loss: 1.5056 - val_p_acc: 0.4458
# Epoch 55/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1154 - c_acc: 0.9805 - p_loss: 0.8141 - p_acc: 0.7220WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.1154 - c_acc: 0.9805 - p_loss: 0.8141 - p_acc: 0.7220 - val_p_loss: 1.2555 - val_p_acc: 0.4566
# Epoch 56/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1119 - c_acc: 0.9825 - p_loss: 0.8124 - p_acc: 0.7225WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.1119 - c_acc: 0.9825 - p_loss: 0.8124 - p_acc: 0.7225 - val_p_loss: 2.3445 - val_p_acc: 0.4452
# Epoch 57/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1110 - c_acc: 0.9827 - p_loss: 0.8162 - p_acc: 0.7126WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.1110 - c_acc: 0.9827 - p_loss: 0.8162 - p_acc: 0.7126 - val_p_loss: 1.1634 - val_p_acc: 0.5057
# Epoch 58/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1139 - c_acc: 0.9823 - p_loss: 0.8537 - p_acc: 0.7198WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.1139 - c_acc: 0.9823 - p_loss: 0.8537 - p_acc: 0.7198 - val_p_loss: 1.5921 - val_p_acc: 0.4320
# Epoch 59/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1107 - c_acc: 0.9823 - p_loss: 0.8332 - p_acc: 0.7162WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.1107 - c_acc: 0.9823 - p_loss: 0.8332 - p_acc: 0.7162 - val_p_loss: 1.0113 - val_p_acc: 0.6010
# Epoch 60/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1136 - c_acc: 0.9810 - p_loss: 0.7470 - p_acc: 0.7361WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.1136 - c_acc: 0.9810 - p_loss: 0.7470 - p_acc: 0.7361 - val_p_loss: 0.9583 - val_p_acc: 0.6381
# Epoch 61/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1090 - c_acc: 0.9835 - p_loss: 0.7679 - p_acc: 0.7166WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.1090 - c_acc: 0.9835 - p_loss: 0.7679 - p_acc: 0.7166 - val_p_loss: 1.1856 - val_p_acc: 0.5057
# Epoch 62/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1099 - c_acc: 0.9829 - p_loss: 0.7877 - p_acc: 0.7274WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.1099 - c_acc: 0.9829 - p_loss: 0.7877 - p_acc: 0.7274 - val_p_loss: 1.0817 - val_p_acc: 0.5584
# Epoch 63/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0995 - c_acc: 0.9855 - p_loss: 0.7776 - p_acc: 0.7238WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.0995 - c_acc: 0.9855 - p_loss: 0.7776 - p_acc: 0.7238 - val_p_loss: 1.1342 - val_p_acc: 0.5512
# Epoch 64/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1050 - c_acc: 0.9833 - p_loss: 0.8095 - p_acc: 0.7177WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.1050 - c_acc: 0.9833 - p_loss: 0.8095 - p_acc: 0.7177 - val_p_loss: 1.4118 - val_p_acc: 0.4254
# Epoch 65/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1024 - c_acc: 0.9853 - p_loss: 0.7647 - p_acc: 0.7405WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.1024 - c_acc: 0.9853 - p_loss: 0.7647 - p_acc: 0.7405 - val_p_loss: 1.1055 - val_p_acc: 0.5800
# Epoch 66/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0969 - c_acc: 0.9860 - p_loss: 0.7640 - p_acc: 0.7357WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.0969 - c_acc: 0.9860 - p_loss: 0.7640 - p_acc: 0.7357 - val_p_loss: 1.3333 - val_p_acc: 0.4775
# Epoch 67/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1018 - c_acc: 0.9857 - p_loss: 0.7954 - p_acc: 0.7202WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.1018 - c_acc: 0.9857 - p_loss: 0.7954 - p_acc: 0.7202 - val_p_loss: 1.1941 - val_p_acc: 0.4620
# Epoch 68/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1058 - c_acc: 0.9840 - p_loss: 0.7401 - p_acc: 0.7360WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.1058 - c_acc: 0.9840 - p_loss: 0.7401 - p_acc: 0.7360 - val_p_loss: 1.1614 - val_p_acc: 0.5075
# Epoch 69/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0963 - c_acc: 0.9855 - p_loss: 0.7387 - p_acc: 0.7315WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.0963 - c_acc: 0.9855 - p_loss: 0.7387 - p_acc: 0.7315 - val_p_loss: 1.1248 - val_p_acc: 0.5165
# Epoch 70/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.1013 - c_acc: 0.9846 - p_loss: 0.7480 - p_acc: 0.7391WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.1013 - c_acc: 0.9846 - p_loss: 0.7480 - p_acc: 0.7391 - val_p_loss: 1.3996 - val_p_acc: 0.4068
# Epoch 71/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0919 - c_acc: 0.9869 - p_loss: 0.7240 - p_acc: 0.7381WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.0919 - c_acc: 0.9869 - p_loss: 0.7240 - p_acc: 0.7381 - val_p_loss: 1.2555 - val_p_acc: 0.4320
# Epoch 72/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0945 - c_acc: 0.9863 - p_loss: 0.7595 - p_acc: 0.7400WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.0945 - c_acc: 0.9863 - p_loss: 0.7595 - p_acc: 0.7400 - val_p_loss: 2.1899 - val_p_acc: 0.4002
# Epoch 73/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0982 - c_acc: 0.9853 - p_loss: 0.7462 - p_acc: 0.7478WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.0982 - c_acc: 0.9853 - p_loss: 0.7462 - p_acc: 0.7478 - val_p_loss: 1.0285 - val_p_acc: 0.5686
# Epoch 74/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0944 - c_acc: 0.9863 - p_loss: 0.7771 - p_acc: 0.7312WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.0944 - c_acc: 0.9863 - p_loss: 0.7771 - p_acc: 0.7312 - val_p_loss: 1.1619 - val_p_acc: 0.5339
# Epoch 75/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0928 - c_acc: 0.9863 - p_loss: 0.7386 - p_acc: 0.7500WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.0928 - c_acc: 0.9863 - p_loss: 0.7386 - p_acc: 0.7500 - val_p_loss: 1.9161 - val_p_acc: 0.4092
# Epoch 76/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0946 - c_acc: 0.9864 - p_loss: 0.7540 - p_acc: 0.7280WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.0946 - c_acc: 0.9864 - p_loss: 0.7540 - p_acc: 0.7280 - val_p_loss: 1.4437 - val_p_acc: 0.3379
# Epoch 77/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0925 - c_acc: 0.9872 - p_loss: 0.7044 - p_acc: 0.7460WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.0925 - c_acc: 0.9872 - p_loss: 0.7044 - p_acc: 0.7460 - val_p_loss: 1.1392 - val_p_acc: 0.5249
# Epoch 78/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0939 - c_acc: 0.9866 - p_loss: 0.6934 - p_acc: 0.7472WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.0939 - c_acc: 0.9866 - p_loss: 0.6934 - p_acc: 0.7472 - val_p_loss: 1.2974 - val_p_acc: 0.4721
# Epoch 79/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0850 - c_acc: 0.9887 - p_loss: 0.7656 - p_acc: 0.7436WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.0850 - c_acc: 0.9887 - p_loss: 0.7656 - p_acc: 0.7436 - val_p_loss: 1.1281 - val_p_acc: 0.5512
# Epoch 80/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0938 - c_acc: 0.9873 - p_loss: 0.7456 - p_acc: 0.7451WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.0938 - c_acc: 0.9873 - p_loss: 0.7456 - p_acc: 0.7451 - val_p_loss: 1.3281 - val_p_acc: 0.5333
# Epoch 81/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0847 - c_acc: 0.9887 - p_loss: 0.6947 - p_acc: 0.7607WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.0847 - c_acc: 0.9887 - p_loss: 0.6947 - p_acc: 0.7607 - val_p_loss: 1.3412 - val_p_acc: 0.5033
# Epoch 82/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0869 - c_acc: 0.9885 - p_loss: 0.7640 - p_acc: 0.7418WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.0869 - c_acc: 0.9885 - p_loss: 0.7640 - p_acc: 0.7418 - val_p_loss: 1.1562 - val_p_acc: 0.5153
# Epoch 83/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0841 - c_acc: 0.9884 - p_loss: 0.7504 - p_acc: 0.7393WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.0841 - c_acc: 0.9884 - p_loss: 0.7504 - p_acc: 0.7393 - val_p_loss: 1.3738 - val_p_acc: 0.4002
# Epoch 84/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0839 - c_acc: 0.9889 - p_loss: 0.7461 - p_acc: 0.7409WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.0839 - c_acc: 0.9889 - p_loss: 0.7461 - p_acc: 0.7409 - val_p_loss: 0.9011 - val_p_acc: 0.6812
# Epoch 85/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0853 - c_acc: 0.9882 - p_loss: 0.7930 - p_acc: 0.7316WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.0853 - c_acc: 0.9882 - p_loss: 0.7930 - p_acc: 0.7316 - val_p_loss: 1.8609 - val_p_acc: 0.4733
# Epoch 86/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0879 - c_acc: 0.9877 - p_loss: 0.8089 - p_acc: 0.7298WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.0879 - c_acc: 0.9877 - p_loss: 0.8089 - p_acc: 0.7298 - val_p_loss: 1.2144 - val_p_acc: 0.5482
# Epoch 87/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0828 - c_acc: 0.9887 - p_loss: 0.6997 - p_acc: 0.7545WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.0828 - c_acc: 0.9887 - p_loss: 0.6997 - p_acc: 0.7545 - val_p_loss: 1.8088 - val_p_acc: 0.3823
# Epoch 88/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0802 - c_acc: 0.9899 - p_loss: 0.7087 - p_acc: 0.7481WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.0802 - c_acc: 0.9899 - p_loss: 0.7087 - p_acc: 0.7481 - val_p_loss: 1.4346 - val_p_acc: 0.4847
# Epoch 89/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0762 - c_acc: 0.9908 - p_loss: 0.7088 - p_acc: 0.7527WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.0762 - c_acc: 0.9908 - p_loss: 0.7088 - p_acc: 0.7527 - val_p_loss: 1.0464 - val_p_acc: 0.6117
# Epoch 90/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0815 - c_acc: 0.9889 - p_loss: 0.6830 - p_acc: 0.7580WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.0815 - c_acc: 0.9889 - p_loss: 0.6830 - p_acc: 0.7580 - val_p_loss: 1.0644 - val_p_acc: 0.6267
# Epoch 91/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0825 - c_acc: 0.9886 - p_loss: 0.6956 - p_acc: 0.7523WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.0825 - c_acc: 0.9886 - p_loss: 0.6956 - p_acc: 0.7523 - val_p_loss: 1.0824 - val_p_acc: 0.5596
# Epoch 92/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0817 - c_acc: 0.9884 - p_loss: 0.6578 - p_acc: 0.7623WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.0817 - c_acc: 0.9884 - p_loss: 0.6578 - p_acc: 0.7623 - val_p_loss: 1.2090 - val_p_acc: 0.5249
# Epoch 93/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0832 - c_acc: 0.9882 - p_loss: 0.7180 - p_acc: 0.7433WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.0832 - c_acc: 0.9882 - p_loss: 0.7180 - p_acc: 0.7433 - val_p_loss: 1.3268 - val_p_acc: 0.5087
# Epoch 94/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0749 - c_acc: 0.9908 - p_loss: 0.7034 - p_acc: 0.7586WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.0749 - c_acc: 0.9908 - p_loss: 0.7034 - p_acc: 0.7586 - val_p_loss: 0.9508 - val_p_acc: 0.6171
# Epoch 95/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0788 - c_acc: 0.9896 - p_loss: 0.6829 - p_acc: 0.7572WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.0788 - c_acc: 0.9896 - p_loss: 0.6829 - p_acc: 0.7572 - val_p_loss: 1.1557 - val_p_acc: 0.5225
# Epoch 96/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0732 - c_acc: 0.9905 - p_loss: 0.6274 - p_acc: 0.7750WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 569s 3s/step - c_loss: 0.0732 - c_acc: 0.9905 - p_loss: 0.6274 - p_acc: 0.7750 - val_p_loss: 1.0331 - val_p_acc: 0.6123
# Epoch 97/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0778 - c_acc: 0.9910 - p_loss: 0.6447 - p_acc: 0.7658WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.0778 - c_acc: 0.9910 - p_loss: 0.6447 - p_acc: 0.7658 - val_p_loss: 0.8652 - val_p_acc: 0.6992
# Epoch 98/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0749 - c_acc: 0.9915 - p_loss: 0.6857 - p_acc: 0.7566WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.0749 - c_acc: 0.9915 - p_loss: 0.6857 - p_acc: 0.7566 - val_p_loss: 1.1374 - val_p_acc: 0.5362
# Epoch 99/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0729 - c_acc: 0.9910 - p_loss: 0.6608 - p_acc: 0.7587WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.0729 - c_acc: 0.9910 - p_loss: 0.6608 - p_acc: 0.7587 - val_p_loss: 1.0466 - val_p_acc: 0.6040
# Epoch 100/100
# 209/209 [==============================] - ETA: 0s - c_loss: 0.0788 - c_acc: 0.9893 - p_loss: 0.6913 - p_acc: 0.7611WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 209/209 [==============================] - 570s 3s/step - c_loss: 0.0788 - c_acc: 0.9893 - p_loss: 0.6913 - p_acc: 0.7611 - val_p_loss: 1.3065 - val_p_acc: 0.4530
# Maximal validation accuracy: 69.92%

# %%
plt.plot(pretraining_history.history['c_acc'])
plt.plot(pretraining_history.history['p_acc'])
plt.title('Self-supervised pretraining accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Constrastive', 'Pretraining'], loc='upper left')
plt.show()

# %%
baseline_model.save("../Models/keras_simclr_pretrain_full_69.92%.h5")

# %% [markdown]
# Pretraining with accuracy of 69.92% was achieved with 1% labeled data. Low accuracy during pretraining is expected.

# %% [markdown]
# ### Supervised finetuning of the pretrained encoder

# %%
# Supervised finetuning of the pretrained encoder - Student Net
finetuning_model = keras.Sequential(
    [
        layers.Input(shape=(image_size, image_size, image_channels)),
        get_augmenter(**classification_augmentation),
        pretraining_model.encoder,
        layers.Dense(4),
    ],
    name="finetuning_model",
)
#In the above model initiation, we call the pretraining_model.encoder, sharing the trained resnet with the student net
finetuning_model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc")],
)

callbacks3 = [tf.keras.callbacks.ModelCheckpoint(filepath='../Models/keras_simclr_semi_supervised_model.{epoch:02d}-{val_loss:.2f}.h5',
                                                monitor='val_acc',
                                                mode='max',
                                                save_best_only=True),

]

finetuning_history = finetuning_model.fit(
    labeled_train_dataset, 
    epochs=num_epochs, 
    validation_data=test_dataset,
    callbacks = callbacks3
)
print(
    "Maximal validation accuracy: {:.2f}%".format(
        max(finetuning_history.history["val_acc"]) * 100
    )
)
# Out:
# Epoch 1/100
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# 209/209 [==============================] - 186s 866ms/step - loss: 0.1778 - acc: 0.9429 - val_loss: 0.3056 - val_acc: 0.9185
# Epoch 2/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0843 - acc: 0.9700 - val_loss: 0.3856 - val_acc: 0.9131
# Epoch 3/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0857 - acc: 0.9708 - val_loss: 0.4284 - val_acc: 0.8670
# Epoch 4/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0846 - acc: 0.9717 - val_loss: 0.6939 - val_acc: 0.8508
# Epoch 5/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0941 - acc: 0.9675 - val_loss: 0.4853 - val_acc: 0.8748
# Epoch 6/100
# 209/209 [==============================] - 180s 862ms/step - loss: 0.0750 - acc: 0.9751 - val_loss: 0.3118 - val_acc: 0.9275
# Epoch 7/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0761 - acc: 0.9750 - val_loss: 0.4332 - val_acc: 0.8951
# Epoch 8/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0775 - acc: 0.9742 - val_loss: 0.4249 - val_acc: 0.9059
# Epoch 9/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0645 - acc: 0.9766 - val_loss: 0.3580 - val_acc: 0.9071
# Epoch 10/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0619 - acc: 0.9769 - val_loss: 0.3075 - val_acc: 0.9185
# Epoch 11/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0635 - acc: 0.9789 - val_loss: 0.4567 - val_acc: 0.8999
# Epoch 12/100
# 209/209 [==============================] - 180s 862ms/step - loss: 0.0687 - acc: 0.9747 - val_loss: 0.2597 - val_acc: 0.9287
# Epoch 13/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0635 - acc: 0.9775 - val_loss: 0.4067 - val_acc: 0.9065
# Epoch 14/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0608 - acc: 0.9792 - val_loss: 0.7001 - val_acc: 0.8700
# Epoch 15/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0727 - acc: 0.9763 - val_loss: 0.3914 - val_acc: 0.9107
# Epoch 16/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0679 - acc: 0.9774 - val_loss: 0.2900 - val_acc: 0.9227
# Epoch 17/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0564 - acc: 0.9801 - val_loss: 0.3071 - val_acc: 0.9191
# Epoch 18/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0529 - acc: 0.9826 - val_loss: 0.3601 - val_acc: 0.9071
# Epoch 19/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0600 - acc: 0.9774 - val_loss: 0.3784 - val_acc: 0.9113
# Epoch 20/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0557 - acc: 0.9811 - val_loss: 0.7863 - val_acc: 0.8220
# Epoch 21/100
# 209/209 [==============================] - 179s 859ms/step - loss: 0.0548 - acc: 0.9828 - val_loss: 0.5326 - val_acc: 0.8856
# Epoch 22/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0422 - acc: 0.9874 - val_loss: 0.4471 - val_acc: 0.9053
# Epoch 23/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0675 - acc: 0.9783 - val_loss: 0.6548 - val_acc: 0.8670
# Epoch 24/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0521 - acc: 0.9829 - val_loss: 0.3400 - val_acc: 0.9215
# Epoch 25/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0448 - acc: 0.9829 - val_loss: 0.3892 - val_acc: 0.9107
# Epoch 26/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0530 - acc: 0.9796 - val_loss: 0.2776 - val_acc: 0.9281
# Epoch 27/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0576 - acc: 0.9805 - val_loss: 0.4214 - val_acc: 0.8886
# Epoch 28/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0428 - acc: 0.9856 - val_loss: 0.4132 - val_acc: 0.8910
# Epoch 29/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0499 - acc: 0.9829 - val_loss: 0.3728 - val_acc: 0.8987
# Epoch 30/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0368 - acc: 0.9877 - val_loss: 0.3733 - val_acc: 0.9071
# Epoch 31/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0486 - acc: 0.9826 - val_loss: 0.5140 - val_acc: 0.9017
# Epoch 32/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0465 - acc: 0.9823 - val_loss: 0.4460 - val_acc: 0.9041
# Epoch 33/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0398 - acc: 0.9870 - val_loss: 0.3244 - val_acc: 0.9203
# Epoch 34/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0393 - acc: 0.9853 - val_loss: 0.4478 - val_acc: 0.9035
# Epoch 35/100
# 209/209 [==============================] - 179s 859ms/step - loss: 0.0415 - acc: 0.9849 - val_loss: 0.5016 - val_acc: 0.9011
# Epoch 36/100
# 209/209 [==============================] - 180s 862ms/step - loss: 0.0358 - acc: 0.9874 - val_loss: 0.3340 - val_acc: 0.9311
# Epoch 37/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0381 - acc: 0.9864 - val_loss: 0.4013 - val_acc: 0.9149
# Epoch 38/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0332 - acc: 0.9895 - val_loss: 0.6456 - val_acc: 0.8951
# Epoch 39/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0497 - acc: 0.9817 - val_loss: 0.3596 - val_acc: 0.9065
# Epoch 40/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0424 - acc: 0.9846 - val_loss: 0.4528 - val_acc: 0.8784
# Epoch 41/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0506 - acc: 0.9838 - val_loss: 0.3237 - val_acc: 0.9209
# Epoch 42/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0416 - acc: 0.9840 - val_loss: 0.3481 - val_acc: 0.9101
# Epoch 43/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0405 - acc: 0.9864 - val_loss: 0.4730 - val_acc: 0.8951
# Epoch 44/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0322 - acc: 0.9895 - val_loss: 0.4024 - val_acc: 0.9131
# Epoch 45/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0367 - acc: 0.9873 - val_loss: 0.3010 - val_acc: 0.9263
# Epoch 46/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0295 - acc: 0.9901 - val_loss: 0.5576 - val_acc: 0.9053
# Epoch 47/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0308 - acc: 0.9897 - val_loss: 0.4166 - val_acc: 0.9119
# Epoch 48/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0482 - acc: 0.9820 - val_loss: 0.3572 - val_acc: 0.9161
# Epoch 49/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0333 - acc: 0.9885 - val_loss: 0.4027 - val_acc: 0.9149
# Epoch 50/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0329 - acc: 0.9876 - val_loss: 0.3580 - val_acc: 0.9215
# Epoch 51/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0340 - acc: 0.9883 - val_loss: 0.4464 - val_acc: 0.9143
# Epoch 52/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0322 - acc: 0.9886 - val_loss: 0.4963 - val_acc: 0.9017
# Epoch 53/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0375 - acc: 0.9865 - val_loss: 0.4782 - val_acc: 0.8910
# Epoch 54/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0196 - acc: 0.9933 - val_loss: 0.6176 - val_acc: 0.8993
# Epoch 55/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0423 - acc: 0.9844 - val_loss: 0.4550 - val_acc: 0.9191
# Epoch 56/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0343 - acc: 0.9877 - val_loss: 0.5423 - val_acc: 0.8928
# Epoch 57/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0356 - acc: 0.9889 - val_loss: 0.9390 - val_acc: 0.8586
# Epoch 58/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0268 - acc: 0.9910 - val_loss: 0.5110 - val_acc: 0.9077
# Epoch 59/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0371 - acc: 0.9874 - val_loss: 0.5396 - val_acc: 0.8933
# Epoch 60/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0288 - acc: 0.9901 - val_loss: 0.4173 - val_acc: 0.9227
# Epoch 61/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0158 - acc: 0.9945 - val_loss: 0.6243 - val_acc: 0.8922
# Epoch 62/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0310 - acc: 0.9894 - val_loss: 0.5185 - val_acc: 0.8880
# Epoch 63/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0346 - acc: 0.9877 - val_loss: 0.6224 - val_acc: 0.8993
# Epoch 64/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0368 - acc: 0.9871 - val_loss: 0.6189 - val_acc: 0.8987
# Epoch 65/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0248 - acc: 0.9916 - val_loss: 0.4737 - val_acc: 0.9119
# Epoch 66/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0266 - acc: 0.9907 - val_loss: 0.5611 - val_acc: 0.9143
# Epoch 67/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0333 - acc: 0.9885 - val_loss: 0.5024 - val_acc: 0.9017
# Epoch 68/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0265 - acc: 0.9900 - val_loss: 0.8637 - val_acc: 0.8340
# Epoch 69/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0318 - acc: 0.9900 - val_loss: 0.5397 - val_acc: 0.9065
# Epoch 70/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0223 - acc: 0.9919 - val_loss: 0.5761 - val_acc: 0.8904
# Epoch 71/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0278 - acc: 0.9915 - val_loss: 0.3804 - val_acc: 0.9185
# Epoch 72/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0211 - acc: 0.9922 - val_loss: 0.3785 - val_acc: 0.9167
# Epoch 73/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0255 - acc: 0.9916 - val_loss: 0.9781 - val_acc: 0.8286
# Epoch 74/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0282 - acc: 0.9900 - val_loss: 0.5210 - val_acc: 0.9191
# Epoch 75/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0204 - acc: 0.9928 - val_loss: 0.4857 - val_acc: 0.9197
# Epoch 76/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0220 - acc: 0.9927 - val_loss: 0.4194 - val_acc: 0.9125
# Epoch 77/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0338 - acc: 0.9900 - val_loss: 0.3685 - val_acc: 0.9197
# Epoch 78/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0280 - acc: 0.9897 - val_loss: 0.6592 - val_acc: 0.8856
# Epoch 79/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0197 - acc: 0.9930 - val_loss: 0.3507 - val_acc: 0.9275
# Epoch 80/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0273 - acc: 0.9906 - val_loss: 0.8207 - val_acc: 0.8856
# Epoch 81/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0242 - acc: 0.9918 - val_loss: 0.6336 - val_acc: 0.9053
# Epoch 82/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0288 - acc: 0.9895 - val_loss: 0.6078 - val_acc: 0.9023
# Epoch 83/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0235 - acc: 0.9907 - val_loss: 0.7206 - val_acc: 0.9017
# Epoch 84/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0230 - acc: 0.9918 - val_loss: 0.4791 - val_acc: 0.9029
# Epoch 85/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0199 - acc: 0.9939 - val_loss: 0.5804 - val_acc: 0.9119
# Epoch 86/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0168 - acc: 0.9948 - val_loss: 0.4896 - val_acc: 0.9143
# Epoch 87/100
# 209/209 [==============================] - 180s 861ms/step - loss: 0.0355 - acc: 0.9871 - val_loss: 0.4881 - val_acc: 0.9113
# Epoch 88/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0179 - acc: 0.9943 - val_loss: 0.4110 - val_acc: 0.9191
# Epoch 89/100
# 209/209 [==============================] - 180s 862ms/step - loss: 0.0201 - acc: 0.9924 - val_loss: 0.2827 - val_acc: 0.9335
# Epoch 90/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0216 - acc: 0.9925 - val_loss: 0.3190 - val_acc: 0.9197
# Epoch 91/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0194 - acc: 0.9930 - val_loss: 0.5444 - val_acc: 0.9149
# Epoch 92/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0216 - acc: 0.9930 - val_loss: 0.4752 - val_acc: 0.9161
# Epoch 93/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0217 - acc: 0.9933 - val_loss: 0.7390 - val_acc: 0.8592
# Epoch 94/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0319 - acc: 0.9891 - val_loss: 0.4426 - val_acc: 0.9173
# Epoch 95/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0214 - acc: 0.9937 - val_loss: 0.4064 - val_acc: 0.9245
# Epoch 96/100
# 209/209 [==============================] - 180s 860ms/step - loss: 0.0200 - acc: 0.9922 - val_loss: 0.3922 - val_acc: 0.9257
# Epoch 97/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0228 - acc: 0.9924 - val_loss: 0.5706 - val_acc: 0.9029
# Epoch 98/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0186 - acc: 0.9928 - val_loss: 0.5149 - val_acc: 0.9167
# Epoch 99/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0174 - acc: 0.9951 - val_loss: 0.3106 - val_acc: 0.9323
# Epoch 100/100
# 209/209 [==============================] - 180s 859ms/step - loss: 0.0112 - acc: 0.9964 - val_loss: 0.4748 - val_acc: 0.9143
# Maximal validation accuracy: 93.35%

# %%
plt.plot(finetuning_history.history['acc'])
plt.plot(finetuning_history.history['val_acc'])
plt.title('Supervised Finetuning accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
finetuning_model.save("../Models/keras_simclr_semi_supervised_full_93.35%.h5")

# %% [markdown]
# 93.35% accuracy was achieved after finetuning the supervised model with self-supervised pretrained model.
# Next steps: Use 10% dataset with more epochs (200).

# %%
finetuning_model.load_weights('../Models/keras_simclr_semi_supervised_model.12-0.26.h5')

# %%
finetuning_model.evaluate(test_batch)
# Out:
# 968/968 [==============================] - 28s 29ms/step - loss: 0.1104 - acc: 0.9597
# [0.11044257879257202, 0.9597107172012329]

# %% [markdown]
# Semi-supervised learning model on 10% labeled data achieved 95.97% accuracy.

# %%
# The classification accuracies of the baseline and the pretraining + finetuning process:
def plot_training_curves(pretraining_history, finetuning_history, baseline_history):
    for metric_key, metric_name in zip(["accuracy", "loss"], ["accuracy", "loss"]):
        plt.figure(figsize=(8, 5), dpi=100)
        plt.plot(
            baseline_history.history[f"val_{metric_key}"], label="supervised baseline"
        )
        plt.plot(
            pretraining_history.history[f"val_p_acc"],

            #pretraining_history.history[f"val_p_{metric_key}"],
            label="self-supervised pretraining",
        )
        plt.plot(
            finetuning_history.history[f"val_acc"],
            #finetuning_history.history[f"val_{metric_key}"],
            label="supervised finetuning",
        )
        plt.legend()
        plt.title(f"Classification {metric_name} during training")
        plt.xlabel("epochs")
        plt.ylabel(f"validation {metric_name}")


plot_training_curves(pretraining_history, finetuning_history, baseline_history)

# %% [markdown]
# # Acknowledgement & Reference

# %% [markdown]
# - simCLR model was adapted from [keras.io](https://keras.io/examples/vision/semisupervised_simclr/)
